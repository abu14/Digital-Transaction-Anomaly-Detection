# %% [markdown]
# # Data Analysis and Preprocessing

# %%
import os,sys
sys.path.append(os.path.abspath('../scripts'))

# %%
import pandas as pd
import data_analysis_and_preprocessing as dap

# %%
fraud_data = '../data/Fraud_Data.csv'
ipAddress_to_Country = '../data/ipAddress_to_Country.csv'

# %% [markdown]
# ## Load the Datas

# %%
df_fraud = dap.load_data(fraud_data)
df_ipAdress = dap.load_data(ipAddress_to_Country)
# Out:
# 2024-10-21 19:38:14,739 - root - INFO - loading the data
# 2024-10-21 19:38:15,233 - root - INFO - loading the data

# %% [markdown]
# ## data set overview

# %%
dap.data_set_overview(df_fraud)
dap.data_set_overview(df_ipAdress)
# Out:
# 2024-10-21 19:38:15,356 - root - INFO - data set overview
# 2024-10-21 19:38:15,358 - root - INFO - description of the data set
# 2024-10-21 19:38:15,441 - root - INFO - data type of the data frame columns :
# 2024-10-21 19:38:15,444 - root - ERROR - error occured while performing the overview of the data set: 'DataFrame' object has no attribute 'dtype'
# 2024-10-21 19:38:15,446 - root - INFO - data set overview
# 2024-10-21 19:38:15,448 - root - INFO - description of the data set
# 2024-10-21 19:38:15,471 - root - INFO - data type of the data frame columns :
# 2024-10-21 19:38:15,473 - root - ERROR - error occured while performing the overview of the data set: 'DataFrame' object has no attribute 'dtype'
#              user_id  purchase_value            age    ip_address  \
# count  151112.000000   151112.000000  151112.000000  1.511120e+05
# mean   200171.040970       36.935372      33.140704  2.152145e+09
# std    115369.285024       18.322762       8.617733  1.248497e+09
# ...

# %% [markdown]
# #### we can see the dataset description from this

# %% [markdown]
# ## Displaying and handling the missing values

# %%
dap.missing_values(df_fraud)
dap.missing_values(df_ipAdress)
# Out:
# 2024-10-21 19:38:15,488 - root - INFO - displying the missing values is there is any
# 2024-10-21 19:38:15,540 - root - INFO - displying the missing values is there is any
# user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# dtype: int64
# lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64

# %% [markdown]
# #### as we can see there is no missing values in both of the data set

# %% [markdown]
# ## Data Cleaning and handling the duplicates and correcting the data types

# %%
df_fraud=dap.data_cleaning(df_fraud)
df_ipAdress=dap.data_cleaning(df_ipAdress)
# Out:
# 2024-10-21 19:38:15,564 - root - INFO - cleaning the data
# 2024-10-21 19:38:15,567 - root - INFO - removing the duplicatged values
# 2024-10-21 19:38:15,868 - root - INFO - correcting the data dypes
# 2024-10-21 19:38:15,874 - root - INFO - cleaning the data
# 2024-10-21 19:38:15,876 - root - INFO - removing the duplicatged values
# 2024-10-21 19:38:15,923 - root - INFO - correcting the data dypes

# %%
dap.perform_full_eda(df_fraud)
dap.perform_full_eda(df_ipAdress)
# Out:
# 2024-10-21 19:38:15,939 - root - INFO - Starting full Exploratory Data Analysis (EDA)
# 2024-10-21 19:38:15,941 - root - INFO - Performing univariate analysis on numerical columns
# 2024-10-21 19:38:16,005 - root - INFO - Plotting histogram for user_id
# 2024-10-21 19:38:17,170 - root - INFO - Plotting boxplot for user_id
# 2024-10-21 19:38:17,780 - root - INFO - Plotting histogram for purchase_value
# 2024-10-21 19:38:19,565 - root - INFO - Plotting boxplot for purchase_value
# 2024-10-21 19:38:19,950 - root - INFO - Plotting histogram for age
# 2024-10-21 19:38:21,287 - root - INFO - Plotting boxplot for age
# 2024-10-21 19:38:21,712 - root - INFO - Plotting histogram for ip_address
# 2024-10-21 19:38:22,685 - root - INFO - Plotting boxplot for ip_address
# 2024-10-21 19:38:23,174 - root - INFO - Plotting histogram for class
# 2024-10-21 19:38:24,561 - root - INFO - Plotting boxplot for class
# ...

# %%
dap.plot_datetime_aggregations(df_fraud)
dap.plot_datetime_aggregations(df_ipAdress)
# Out:
# 2024-10-21 19:43:47,508 - root - INFO - Performing univariate analysis for datetime features
# 2024-10-21 19:43:47,708 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-21 19:43:47,783 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-21 19:43:47,977 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %% [markdown]
# ## Merging the two data sets

# %%
merged_df = dap.merge_datasets_for_geolocation(df_fraud,df_ipAdress)
merged_df.head()
# Out:
# An error occurred during merging: 732758368.79972 does not appear to be an IPv4 or IPv6 address
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class  signup_hour  \
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0           22
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0           20
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1           18
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0           21
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0            7
#
# ...

# %% [markdown]
# ### saving the merged data set

# %%
merged_df.to_csv('../data/mergeddf.csv')
